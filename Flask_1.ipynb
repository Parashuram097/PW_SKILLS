# %%
"""
Q1. What is Flask Framework? What are the advantages of Flask Framework?
"""

"""
Flask is a micro web framework for Python, designed to be lightweight and easy to use. 
It provides the necessary tools and libraries to build web applications and APIs in a simple and efficient manner.


                                    Advantages of Flask Framework

1-Lightweight and Minimalistic: Flask is known for its simplicity and minimalistic design. It has a small core and provides only the essential features, allowing developers to have more control over their code and project structure.

2-Easy to Get Started: Flask has a straightforward and intuitive API, making it easy for beginners to understand and start building web applications quickly. The learning curve is relatively low compared to other web frameworks.
"""

# %%
"""
Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.
"""

from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello():
    return 'Hello World!!'

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ![flask1.png](attachment:flask1.png)

# %%
"""
Q3. What is App routing in Flask? Why do we use app routes?
"""

"""
app routing refers to the process of mapping URLs to specific functions or views in your web application. 
It allows you to define different routes for different URLs and associate them with the corresponding functions
that handle the requests.

The @app.route decorator in Flask is used to define routes.

"""

# %%
"""
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:

Company Name: ABC Corporation

Location: India

Contact Detail: 999-999-9999

Attach the screenshot of the output in Jupyter Notebook.
"""

from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def details():
    company_name = 'ABC Corporation'
    location = 'India'
    contact_detail = '999-999-9999'

    return f"Company Name: {company_name}<br>" \
           f"Location: {location}<br>" \
           f"Contact Detail: {contact_detail}"

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
"""
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.
"""

"""
the url_for() function is used for URL building. It generates a URL for a given endpoint, 
taking into account the routes defined in the application's routes configuration.

The url_for() function takes the endpoint name as the first argument and optional keyword arguments 
representing the values to be substituted in the route's URL pattern. It automatically handles the dynamic parts
of the URL and generates a complete URL that can be used to access a specific route in the application.
"""
