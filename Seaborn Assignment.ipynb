# %%
"""
Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
"""



"""
Scatter Plot (scatterplot): A scatter plot displays the relationship between two variables as individual data points. 
It is useful for visualizing patterns, trends, and correlations in the data.

Bar Plot (barplot): A bar plot represents categorical data using rectangular bars. 
It can be used to compare values across different categories or show the distribution of a variable.

Histogram (histplot): A histogram visualizes the distribution of a single numerical variable by dividing it into bins 
and showing the frequency or density of values falling into each bin. It helps in understanding the data's 
underlying distribution and identifying outliers or skewness.

Box Plot (boxplot): A box plot displays the distribution of a numerical variable across different categories. 
It shows the quartiles, median, and any potential outliers in the data. It is useful for comparing distributions, 
identifying outliers, and assessing the spread of the data.

Heatmap (heatmap): A heatmap is a 2D plot that represents the correlation or relationship between two variables
in a matrix form. It uses color gradients to represent the intensity or strength of the relationship. 
Heatmaps are helpful in analyzing relationships, identifying patterns, and visualizing correlations in large datasets.

"""

# %%
"""
Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions.

Note: timepoint, signal, event, and region are columns in the fmri dataset.

"""

import seaborn as sns
import matplotlib.pyplot as plt

fmri_data = sns.load_dataset("fmri")
sns.lineplot(data=fmri_data, x="timepoint", y="signal", hue="event", style="region")

plt.xlabel("Timepoint")
plt.ylabel("Signal")
plt.title("Line Plot of FMRI Data")
plt.show()

# %%
"""
Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'.

Note: pclass, age, and fare are columns in the titanic dataset.

"""


titanic_data = sns.load_dataset("titanic")


plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.boxplot(data=titanic_data, x="pclass", y="age")
plt.xlabel("Passenger Class")
plt.ylabel("Age")
plt.title("Box Plot: Age by Passenger Class")

plt.subplot(1, 2, 2)
sns.boxplot(data=titanic_data, x="pclass", y="fare")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.title("Box Plot: Fare by Passenger Class")

plt.tight_layout()
plt.show()

# %%
"""
Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset.
"""

diamonds_data = sns.load_dataset("diamonds")
sns.histplot(data=diamonds_data, x='price', hue='cut', multiple='stack')


plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Histogram of Diamond Prices by Cut')
plt.show()

# %%
"""
Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset.
"""

iris_data = sns.load_dataset("iris")
sns.pairplot(data=iris_data, hue="species")
plt.show()

# %%
"""
Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
"""

flights_data = sns.load_dataset("flights")
flights_matrix = flights_data.pivot("month", "year", "passengers")
sns.heatmap(data=flights_matrix, cmap="YlGnBu")

plt.xlabel("Year")
plt.ylabel("Month")
plt.title("Heatmap of Flights")
plt.show()
